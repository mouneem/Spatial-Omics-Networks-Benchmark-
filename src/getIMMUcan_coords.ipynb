# %%
import os
import sys
import pathlib
import glob

# %%
os.getcwd()
# Out:
# '/home/abdelmounim.essabbar/Projects/Spatial-Omics-Networks-Benchmark-/src'

# %%
IMMUcan_path = '../../IMMUcan_data/data/IMC/'



def get_matching_files(directory, pattern):
    matching_files = []
    # Use os.walk to traverse the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        # Use glob to match the pattern in the current directory
        for file in glob.glob(os.path.join(root, pattern)):
            matching_files.append(file)
    return matching_files

# Example usage:
file_pattern = '*cell_metadata*.csv'  # Change this pattern as needed
txt_files = get_matching_files(IMMUcan_path, file_pattern)

# %%
import pandas as pd
import csv

All_Cells = []

for file in txt_files[-5:]:
    df = pd.read_csv(file)
    metadata = df[['Pos_X','Pos_Y','sample_id','tumor_patches','ROI']]
    metadata['TLS'] = False
    metadata[metadata['ROI']==4] ['TLS'] = True
    All_Cells.append(metadata)
AllCells = pd.concat(All_Cells)
# Out:
# /tmp/ipykernel_2666814/968330620.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['TLS'] = False
# /tmp/ipykernel_2666814/968330620.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['TLS'] = False
# /tmp/ipykernel_2666814/968330620.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Out:
#             Pos_X       Pos_Y  \
# 0       13.000000    0.733333
# 1       32.500000    0.500000
# 2      182.800000    0.850000
# 3      275.500000    0.428571
# 4      290.285714    0.666667
# ...           ...         ...
# 10991   21.043478  597.826087
# 10992  372.842105  598.052632
# 10993  496.433333  597.966667
# 10994  519.333333  597.800000
# 10995  581.150000  598.250000
#
#                                                sample_id  tumor_patches  ROI  \
# 0      IMMUcan_Batch20210506_UPSTREAM_10064569-E1559-...          False    1
# 1      IMMUcan_Batch20210506_UPSTREAM_10064569-E1559-...          False    1
# 2      IMMUcan_Batch20210506_UPSTREAM_10064569-E1559-...           True    1
# 3      IMMUcan_Batch20210506_UPSTREAM_10064569-E1559-...          False    1
# 4      IMMUcan_Batch20210506_UPSTREAM_10064569-E1559-...          False    1
# ...                                                  ...            ...  ...
# ...
